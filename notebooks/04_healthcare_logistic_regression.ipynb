# %%
import os

# Set working directory to project root always
# Works regardless of where the notebook is saved
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
os.chdir(project_root)

print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: c:\Users\DELL\OneDrive\Documents\SRM\Churn_Analysis

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# Load preprocessed data
X_train = np.load('outputs/X_train_healthcare.npy')
X_test  = np.load('outputs/X_test_healthcare.npy')

y_train = np.load('outputs/y_train_healthcare.npy')
y_test  = np.load('outputs/y_test_healthcare.npy')

feature_names = pd.read_csv(
    'outputs/healthcare_feature_names.csv'
).squeeze().tolist()

print("Training shape :", X_train.shape)
print("Test shape     :", X_test.shape)
# Out:
# Training shape : (2188, 18)
# Test shape     : (400, 18)

# %%
lr_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

lr_model.fit(
    X_train,
    y_train
)

print("Healthcare Logistic Regression trained successfully")
# Out:
# Healthcare Logistic Regression trained successfully

# %%
y_pred = lr_model.predict(X_test)

y_proba = lr_model.predict_proba(
    X_test
)[:,1]

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report
)

acc = accuracy_score(
    y_test,
    y_pred
)

prec = precision_score(
    y_test,
    y_pred
)

rec = recall_score(
    y_test,
    y_pred
)

f1 = f1_score(
    y_test,
    y_pred
)

auc = roc_auc_score(
    y_test,
    y_proba
)

print("="*40)
print("Healthcare - Logistic Regression")
print("="*40)

print(f"Accuracy  : {acc:.4f}")
print(f"Precision : {prec:.4f}")
print(f"Recall    : {rec:.4f}")
print(f"F1 Score  : {f1:.4f}")
print(f"ROC-AUC   : {auc:.4f}")

print("="*40)

print(
    classification_report(
        y_test,
        y_pred,
        target_names=[
            'Retained',
            'Churned'
        ]
    )
)
# Out:
# ...
# Healthcare - Logistic Regression
# ...
# Accuracy  : 0.6000
# Precision : 0.7446
# Recall    : 0.6300
# F1 Score  : 0.6825
# ROC-AUC   : 0.6213
# ...
#               precision    recall  f1-score   support
#
#     Retained       0.40      0.54      0.46       127
#      Churned       0.74      0.63      0.68       273
#
#     accuracy                           0.60       400
#    macro avg       0.57      0.58      0.57       400
# weighted avg       0.64      0.60      0.61       400

# %%
from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

cm = confusion_matrix(
    y_test,
    y_pred
)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[
        'Retained',
        'Churned'
    ]
)

plt.figure(figsize=(6,5))

disp.plot(
    cmap='Blues',
    colorbar=False
)

plt.title(
    'Healthcare Logistic Regression'
)

plt.show()

# %%
from sklearn.metrics import (
    RocCurveDisplay
)

plt.figure(figsize=(6,5))

RocCurveDisplay.from_predictions(
    y_test,
    y_proba,
    name='Logistic Regression'
)

plt.plot(
    [0,1],
    [0,1],
    '--',
    color='gray'
)

plt.title(
    'Healthcare ROC Curve'
)

plt.show()

# %%
import joblib
import os

os.makedirs(
    'outputs',
    exist_ok=True
)

joblib.dump(
    lr_model,
    'outputs/lr_model_healthcare.pkl'
)

print(
    "Model saved successfully"
)
# Out:
# Model saved successfully

# %%
results = {
    'Sector'    : 'Healthcare',
    'Model'     : 'Logistic Regression',
    'Accuracy'  : round(acc,4),
    'Precision' : round(prec,4),
    'Recall'    : round(rec,4),
    'F1'        : round(f1,4),
    'ROC_AUC'   : round(auc,4)
}

results_df = pd.DataFrame(
    [results]
)

results_df.to_csv(
    'outputs/results/healthcare_lr_results.csv',
    index=False
)

print(results_df)
# Out:
#        Sector                Model  Accuracy  Precision  Recall      F1  \
# 0  Healthcare  Logistic Regression       0.6     0.7446    0.63  0.6825
#
#    ROC_AUC
# 0   0.6213
