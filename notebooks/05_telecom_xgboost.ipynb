# %%
import os

# Set working directory to project root always`n
# Works regardless of where the notebook is saved`n
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
project_root = os.path.abspath(os.path.join(notebook_dir, '..'))
os.chdir(project_root)

print("Working directory set to:", os.getcwd())
# Out:
# Working directory set to: c:\Users\DELL\OneDrive\Documents\SRM\Churn_Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score, precision_score,
    recall_score, f1_score, roc_auc_score,
    confusion_matrix, classification_report,
    ConfusionMatrixDisplay, RocCurveDisplay
)

X_train = np.load('outputs/X_train_telecom.npy')
X_test  = np.load('outputs/X_test_telecom.npy')
y_train = np.load('outputs/y_train_telecom.npy')
y_test  = np.load('outputs/y_test_telecom.npy')

feature_names = pd.read_csv(
    'outputs/telecom_feature_names.csv'
).squeeze().tolist()

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
# Out:
# X_train: (5634, 23)
# X_test : (1409, 23)

# %%
xgb_model = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=4,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss',
    verbosity=0
)

xgb_model.fit(X_train, y_train)
print("XGBoost trained successfully")
# Out:
# XGBoost trained successfully

# %%
y_pred  = xgb_model.predict(X_test)
y_proba = xgb_model.predict_proba(X_test)[:,1]

acc  = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec  = recall_score(y_test, y_pred)
f1   = f1_score(y_test, y_pred)
auc  = roc_auc_score(y_test, y_proba)

print("="*40)
print("  XGBoost â€” Telecom")
print("="*40)
print(f"  Accuracy  : {acc:.4f}")
print(f"  Precision : {prec:.4f}")
print(f"  Recall    : {rec:.4f}")
print(f"  F1 Score  : {f1:.4f}")
print(f"  ROC-AUC   : {auc:.4f}")
print("="*40)
print(classification_report(
    y_test, y_pred,
    target_names=['No Churn','Churn']
))
# Out:
# ========================================
#   XGBoost â€” Telecom
# ========================================
#   Accuracy  : 0.7935
#   Precision : 0.6436
#   Recall    : 0.4973
#   F1 Score  : 0.5611
#   ROC-AUC   : 0.8401
# ========================================
#               precision    recall  f1-score   support
#
#     No Churn       0.83      0.90      0.86      1035
#        Churn       0.64      0.50      0.56       374
#
#     accuracy                           0.79      1409
#    macro avg       0.74      0.70      0.71      1409
# weighted avg       0.78      0.79      0.78      1409

# %%
import os
os.makedirs('outputs/plots/telecom', exist_ok=True)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['No Churn','Churn']
).plot(ax=axes[0], colorbar=False, cmap='Oranges')
axes[0].set_title('Confusion Matrix â€” XGBoost')

RocCurveDisplay.from_predictions(
    y_test, y_proba,
    ax=axes[1],
    name='XGBoost',
    color='#D85A30'
)
axes[1].plot([0,1],[0,1],'--',color='gray',
             label='Random baseline')
axes[1].set_title('ROC Curve â€” XGBoost')
axes[1].legend()

plt.tight_layout()
plt.savefig(
    'outputs/plots/telecom/10_xgb_evaluation.png',
    bbox_inches='tight'
)
plt.show()
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_plotting.py:176: FutureWarning: `**kwargs` is deprecated and will be removed in 1.9. Pass all matplotlib arguments to `curve_kwargs` as a dictionary instead.
#   warnings.warn(

# %%
importances = xgb_model.feature_importances_
feat_df = pd.DataFrame({
    'Feature'   : feature_names,
    'Importance': importances
}).sort_values('Importance', ascending=False)

print("Top 10 most important features:")
print(feat_df.head(10).to_string(index=False))

plt.figure(figsize=(10, 7))
sns.barplot(
    data=feat_df.head(15),
    x='Importance',
    y='Feature',
    palette='rocket'
)
plt.title('Feature Importance â€” XGBoost (Telecom)')
plt.xlabel('Importance Score')
plt.tight_layout()
plt.savefig(
    'outputs/plots/telecom/11_xgb_feature_importance.png',
    bbox_inches='tight'
)
plt.show()
# Out:
# Top 10 most important features:
#                        Feature  Importance
#    InternetService_Fiber optic    0.359212
#              Contract_Two year    0.165412
#              Contract_One year    0.131435
#             InternetService_No    0.078116
#                StreamingMovies    0.034116
# PaymentMethod_Electronic check    0.033490
#                         tenure    0.030581
#                 OnlineSecurity    0.019934
#               PaperlessBilling    0.016621
#                    TechSupport    0.016465
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24336\3426082907.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
existing = pd.read_csv('outputs/results/telecom_results.csv')

new_row = pd.DataFrame([{
    'Sector'   : 'Telecom',
    'Model'    : 'XGBoost',
    'Accuracy' : round(acc, 4),
    'Precision': round(prec, 4),
    'Recall'   : round(rec, 4),
    'F1'       : round(f1, 4),
    'ROC_AUC'  : round(auc, 4)
}])

updated = pd.concat([existing, new_row], ignore_index=True)
updated.to_csv(
    'outputs/results/telecom_results.csv',
    index=False
)

print("Results table so far:")
print(updated.to_string(index=False))
# Out:
# Results table so far:
#  Sector               Model  Accuracy  Precision  Recall     F1  ROC_AUC
# Telecom Logistic Regression    0.8055     0.6582  0.5561 0.6029   0.8421
# Telecom       Random Forest    0.7899     0.6291  0.5080 0.5621   0.8244
# Telecom             XGBoost    0.7935     0.6436  0.4973 0.5611   0.8401

# %%
import joblib
scaler = joblib.load('outputs/scaler_telecom.pkl')

# High risk customer
high_risk = pd.DataFrame(
    [np.zeros(len(feature_names))],
    columns=feature_names
)
high_risk['gender']           = 1
high_risk['tenure']           = 2
high_risk['MonthlyCharges']   = 85.0
high_risk['TotalCharges']     = 170.0
high_risk['TechSupport']      = 0
high_risk['OnlineSecurity']   = 0
high_risk['PaperlessBilling'] = 1

col = [c for c in feature_names if 'Fiber' in c]
if col: high_risk[col[0]] = 1
col = [c for c in feature_names if 'Electronic' in c]
if col: high_risk[col[0]] = 1

high_risk[['tenure','MonthlyCharges','TotalCharges']] = \
    scaler.transform(
        high_risk[['tenure','MonthlyCharges','TotalCharges']]
    )

pred1 = xgb_model.predict(high_risk.values)
prob1 = xgb_model.predict_proba(high_risk.values)[:,1]
print(f"High-risk â†’ {'CHURN' if pred1[0]==1 else 'STAY'} | {prob1[0]*100:.1f}%")

# Loyal customer
loyal = pd.DataFrame(
    [np.zeros(len(feature_names))],
    columns=feature_names
)
loyal['tenure']         = 60
loyal['MonthlyCharges'] = 25.0
loyal['TotalCharges']   = 1500.0
loyal['TechSupport']    = 1
loyal['OnlineSecurity'] = 1

col = [c for c in feature_names if 'Two' in c]
if col: loyal[col[0]] = 1
col = [c for c in feature_names if 'Mailed' in c]
if col: loyal[col[0]] = 1

loyal[['tenure','MonthlyCharges','TotalCharges']] = \
    scaler.transform(
        loyal[['tenure','MonthlyCharges','TotalCharges']]
    )

pred2 = xgb_model.predict(loyal.values)
prob2 = xgb_model.predict_proba(loyal.values)[:,1]
print(f"Loyal     â†’ {'CHURN' if pred2[0]==1 else 'STAY'} | {prob2[0]*100:.1f}%")
# Out:
# High-risk â†’ CHURN | 78.8%
# Loyal     â†’ STAY | 0.6%
